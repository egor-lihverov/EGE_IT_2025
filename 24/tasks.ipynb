# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('24.txt').readline()
s = f.split("A")
s = list(filter(lambda x: x.count('E') >= 3, s))
print(len(max(s, key=len)))
# Out:
# 282
# ['DXMNEKRKBUFEGPPHYPNRKHMVILSPLJJIWEVUJPBFP',
#  'EDJEREIEURWSFBGTLJVCKVYYNCWHOQMMHF',
#  'MMHWEWBLPGCFPZXQYLUZRKTEKLQLXNFRVWGGHDPWCRNCKIEEFVYJ',
#  'CHZIXIJEEMVVUDDVQVIBJTJTYVETZUJTFTOZXHJTIIQ',
#  'ETXYBTEGPQQMCNEBXOEXSNF',
#  'XHHYGLFPEHFBIWRHUTMWLBXCPRCHDDWZQMJTWDNLFESSBTXXZKYTKETBVPWBLOCL',
#  'ERDPVMZFICRVEHLHJFOVRKSZURIXNNPQWTDIMDSIBMQFLNEE',
#  'MBZRLQIZGCCUENPIDXPCUGNDZPVNGOIUZSCMXNKJLZZMUDDCLRBIMENSGBZOXNGNRKEORNTEF',
#  'TKTEZOFKCBXCFDDVVJWKMECPZFFKBVJFLKXUNJIE',
#  'ZBSWLSIQLMHHCBSBWYBZLIFFOELXIIPKQMHMEPSKISHHMKLSYIVNRFGUMXCYLHPTHMQGHEIHYY',
#  'FKFQWYBRBTBPWDEETXTWYSTMCTJGSOCJOUWOJGLICDOGTSFSVEWKVLIFUKJQY',
#  'TGKJGLBSNICJFRHDQVQVFSVLEOEXEDJ',
#  'CNQFJDJLVMTDVXPDTZJEUPFCOUEUHRCVVGOZCEEQJKIBNI',
#  'OWSJKPOHNRUFZEUZYBDELCMMZDQDJWQEFKXVDIQJOODHVGUZGKXD',
#  'JMXPTDLVPFTYCYKXRKPRTSJJUVMZZHVBDKFMFPQCYWFIDDVFPZHGQDJEOUNHBOBGULRIJBEEYEYOCY',
#  'YEOTETNYYJHSMJIGLEDRQQ',
#  'QBHMNRIOXLOMSVJOSJFRMBCCPNZSZLCOCZFPRBKZREZJDFTLZFSCJMXBEPHNBDFQUEGE',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('24 (1).txt').readline()
s = f.split("E")

mp = {}

for i in s:
    if i != '':
        if i[0] not in mp:
            mp[i[0]] = 0
        mp[i[0]] += 1

max_v = max(mp.values())

mp
# Out:
# {'F': 1476,
#  'N': 1502,
#  'H': 1527,
#  'P': 1510,
#  'C': 1463,
#  'U': 1523,
#  'T': 1442,
#  'K': 1465,
#  'S': 1471,
#  'W': 1509,
#  'D': 1528,
#  'X': 1395,
#  'B': 1453,
#  'V': 1485,
#  'J': 1492,
#  'A': 1425,
#  'M': 1430,
#  'O': 1455,
#  'L': 1483,
#  'Q': 1513,
#  'G': 1448,
#  'I': 1508,
#  'Z': 1450,
#  'R': 1501,
#  'Y': 1596}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
            L				           I
T ASHDKJA T ASDJ T AJSDLKAJS T SJDASKD T T T 

'''

f = open('24 (1).txt').readline()
s = f.split("E")
cnt = 0
for i in s:
    if len(i) >= 12 and "F" not in i:
        cnt += 1
cnt
# Out:
# 7302

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('24 (3).txt').readline()
s = f.split("V")

s

'YYYX V YYYYYYXYYYYYYYYXYYZTTYT
# Out:
# ['YYYX',
#  'YYYYYYXYYYYYYYYXYYZTTYT',
#  'WUYYYTYYYYYYYYYXYYYYYYYYYYYYYYYWXTYY',
#  'YWYTYUYYYYYYYUZYYYYWYXYYYY',
#  'YYWYTYYYYWYTYZYYYYYYWYYYYYYYYY',
#  'WUYY',
#  'YY',
#  'YYY',
#  'YYYXYYXUYUYTYYZWYZXYYZYZYXYYYY',
#  'YYYWYYYYXYYYYYYYZTYYYUYYYYYZYYYYYYYYYYYUYYWTYYYY',
#  'YYYYYYYYYT',
#  'YYYYYYYYYYYYYXYYYYYYYTZYTY',
#  'YYYYYXYYYYYYYYYYYYYYTZYYYYYY',
#  'Y',
#  'WYYTYYYYYYYYYWYXUYY',
#  'YYYWYYYYYYYYYYYYYYYYYYYTWYYYYYYWYY',
#  'YT',
#  'YTYYY',
#  'YYYZYZYYTYWY',
#  'YYYZYUYYYYYYYYYXYYTYWXYXYYUYTY',
#  'UYYYYYYXYXYYYYYYTTTYYYYY',
#  'YWWYYXY',
#  'YYYYYYYYYYYYYXYZYYYYYYUYYYUWYYUYYYWWYYYYYWYYYWYYYYYYUYYYYYYYYYXTYYY',
#  'YYY',
#  'YYYYYYYYZYYYYYYXWYYYYYYZTYYWXYZTYYYYYYYTYYTUUYYYYYYYYYYYYY',
#  'ZYYYYU',
#  'TYUXYYYYYYXYY',
#  'YYYWYZYYYXZYYYYUYTXUYYYUTXWUYZYYTYYYYYY',
#  'YYUYZYYUYYUWYYYUYYYYYYYYY',
#  'YY',
#  'YYYYUYYYYYYYUYWYTZ',
#  'YYY',
#  'YYY',
#  'YYYYYYWY',
#  'YYTYZTYY',
#  'YYYY',
#  'YYYYYYYZYYYYYYYYYYYYYYYYY',
#  'TYYZXYZYYYYYYYYYYYYY',
#  'YYYYYYY',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
